# %% [markdown]
# Anotações sobre as aulas e Resolução dos desafios
# Variaveis e Objetos:
# Estruturas de Decisões:
# Estruturas de Repetição:
# Lista:
# Dicionários, Sets e Tuplas:
# Numpy:
# Pandas:
# Módulos e Pacotes:

# %% [markdown]
# aula 1 Variáveis e Objetos
